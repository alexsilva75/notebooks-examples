# %%
import skimage as ski
from skimage import io
from skimage import color
import sys
import numpy as np

# %%
img = io.imread('dataset_run/0_Amiloidose/0_Amiloidose_AZAN_0.jpg')
conv_img = color.rgb2hed(img)
io.imshow(conv_img)
# Out:
# C:\Users\alexs\AppData\Local\Programs\Python\Python311\Lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:149: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
conv_img.dtype
# Out:
# dtype('float64')

# %%
np.asarray(conv_img, dtype=np.float64)
# Out:
# array([[[0.04201098, 0.00240315, 0.01332095],
#         [0.03900794, 0.00432631, 0.01366868],
#         [0.03734211, 0.00701448, 0.01540973],
#         ...,
#         [0.05011812, 0.        , 0.00140982],
#         [0.04777158, 0.        , 0.00245214],
#         [0.04844374, 0.        , 0.00288061]],
#
#        [[0.03954395, 0.00426638, 0.01397542],
#         [0.03791216, 0.00568514, 0.01438203],
#         [0.03676481, 0.00837587, 0.01644657],
#         ...,
#         [0.05140498, 0.        , 0.00307874],
#         [0.04969307, 0.        , 0.00252105],
#         [0.04851649, 0.        , 0.00407429]],
#
#        [[0.03554805, 0.00695366, 0.0150821 ],
#         [0.03629874, 0.00709777, 0.01478267],
#         [0.03728783, 0.00834527, 0.01676771],
#         ...,
#         [0.05755378, 0.00059821, 0.00533513],
#         [0.05512264, 0.        , 0.00458971],
#         [0.05414116, 0.        , 0.00570091]],
#
#        ...,
#
#        [[0.07881948, 0.        , 0.        ],
# ...

# %%
io.imsave('0_Amiloidose_AZAN_0.jpg',np.asarray(conv_img, dtype=np.float64))
# Out:
# C:\Users\alexs\AppData\Local\Temp\ipykernel_19816\3342426965.py:1: UserWarning: 0_Amiloidose_AZAN_0.jpg is a low contrast image
#   io.imsave('0_Amiloidose_AZAN_0.jpg',np.asarray(conv_img, dtype=np.float64))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:3098, in fromarray(obj, mode)
#    3097 try:
# -> 3098     mode, rawmode = _fromarray_typemap[typekey]
#    3099 except KeyError as e:
#
# KeyError: ((1, 1, 3), '<f8')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 io.imsave('0_Amiloidose_AZAN_0.jpg',np.asarray(conv_img, dtype=np.float64))
#
# ...
